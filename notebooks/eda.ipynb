# %% [markdown]
# # EDA — Ames House Prices
#
# 1. Load & orient
# 2. Target variable — `SalePrice`
# 3. Missingness
# 4. Univariate
# 5. Bivariate vs target
# 6. Multicollinearity
# 7. Outliers
# 8. Wrap-up

# %% [markdown]
# ## 1. Load & orient
